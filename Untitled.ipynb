# %%
pip freeze
# Out:
# argon2-cffi @ file:///tmp/build/80754af9/argon2-cffi_1596828493937/work
# -e git+https://github.com/argoai/argoverse-api.git@9c9fb20e2651e7164ded706a27a70df04708c885#egg=argoverse
# asciitree==0.3.3
# astroid==2.4.2
# async-generator==1.10
# attrs @ file:///tmp/build/80754af9/attrs_1600298409949/work
# backcall==0.2.0
# bleach @ file:///tmp/build/80754af9/bleach_1600439572647/work
# brotlipy==0.7.0
# cached-property==1.5.2
# certifi==2020.12.5
# cffi @ file:///tmp/build/80754af9/cffi_1600699146221/work
# chardet @ file:///home/conda/feedstock_root/build_artifacts/chardet_1602255302199/work
# cloudpickle==1.6.0
# colour==0.1.5
# cryptography @ file:///home/conda/feedstock_root/build_artifacts/cryptography_1603815246708/work
# cycler==0.10.0
# dataclasses==0.6
# decorator==4.4.2
# defusedxml==0.6.0
# descartes==1.1.0
# dgl==0.5.3
# entrypoints==0.3
# fasteners==0.15
# future==0.18.2
# h5py==3.0.0
# horovod==0.21.0
# ...
